# %%
import pandas as pd

# %%
df = pd.read_csv("training_dataset.csv")

# %%
df
# Out:
#         record_ID      week  store_id  sku_id  total_price  base_price  \
# 0               1  17/01/11      8091  216418      99.0375    111.8625
# 1               2  17/01/11      8091  216419      99.0375     99.0375
# 2               3  17/01/11      8091  216425     133.9500    133.9500
# 3               4  17/01/11      8091  216233     133.9500    133.9500
# 4               5  17/01/11      8091  217390     141.0750    141.0750
# ...           ...       ...       ...     ...          ...         ...
# 150145     212638  09/07/13      9984  223245     235.8375    235.8375
# 150146     212639  09/07/13      9984  223153     235.8375    235.8375
# 150147     212642  09/07/13      9984  245338     357.6750    483.7875
# 150148     212643  09/07/13      9984  547934     141.7875    191.6625
# 150149     212644  09/07/13      9984  679023     234.4125    234.4125
#
#         is_featured_sku  is_display_sku  units_sold
# 0                     0               0          20
# ...

# %%
# create three new useable columns from week. 
df[['day', 'month', 'year']] = df['week'].str.split('/', expand=True)

# %%
# drop unusable week column
df = df.drop('week', axis=1)

# %%
# Import Random forest regressor and not classifier. This is because we will try to predict the units sold. 
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split

X, y = df.drop('units_sold', axis=1) , df['units_sold'] 

# Split data
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2)

# %%
model = RandomForestRegressor(n_jobs = -1) 
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_jobs=-1)

# %%
model.score(X_test, y_test)
# Out:
# 0.7541027434745704

# %%
from sklearn.metrics import root_mean_squared_error

y_pred = model.predict(X_test)
rmse = root_mean_squared_error(y_pred, y_test)

rmse
# Out:
# 29.688392693653874

# %%
df.units_sold.describe()
# Out:
# count    150150.000000
# mean         51.674206
# std          60.207904
# min           1.000000
# 25%          20.000000
# 50%          35.000000
# 75%          62.000000
# max        2876.000000
# Name: units_sold, dtype: float64

# %%
df.units_sold.hist()
# Out:
# <Axes: >

# %%
# note the distribution and there is a severe outlier.

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.scatter(y_pred, y_test)
plt.plot(np.linspace(y_pred.min(), y_pred.max()), np.linspace(y_test.min(), y_test.max()) , color='green')

# %%
df.hist(figsize=(15,8))
plt.show()

# %%
# preprocessing
df = df.drop('record_ID', axis=1)

# %%
len(df.store_id.unique())
# Out:
# 76

# %%
len(df.sku_id.unique())
# Out:
# 28

# %%
# drop units sold that are more that the qauntile below
df = df[df.units_sold < df.units_sold.quantile(0.99)]

# %%
df
# Out:
#         store_id  sku_id  total_price  base_price  is_featured_sku  \
# 0           8091  216418      99.0375    111.8625                0
# 1           8091  216419      99.0375     99.0375                0
# 2           8091  216425     133.9500    133.9500                0
# 3           8091  216233     133.9500    133.9500                0
# 4           8091  217390     141.0750    141.0750                0
# ...          ...     ...          ...         ...              ...
# 150145      9984  223245     235.8375    235.8375                0
# 150146      9984  223153     235.8375    235.8375                0
# 150147      9984  245338     357.6750    483.7875                1
# 150148      9984  547934     141.7875    191.6625                0
# 150149      9984  679023     234.4125    234.4125                0
#
#         is_display_sku  units_sold day month year
# 0                    0          20  17    01   11
# 1                    0          28  17    01   11
# ...

# %%
df.units_sold.hist()
# Out:
# <Axes: >

# %%
# Note the more normal distribution of the units sold

# %%
# one hot encoding
pd.get_dummies(df.store_id, prefix='store')
# Out:
#         store_8023  store_8058  store_8063  store_8091  store_8094  \
# 0            False       False       False        True       False
# 1            False       False       False        True       False
# 2            False       False       False        True       False
# 3            False       False       False        True       False
# 4            False       False       False        True       False
# ...            ...         ...         ...         ...         ...
# 150145       False       False       False       False       False
# 150146       False       False       False       False       False
# 150147       False       False       False       False       False
# 150148       False       False       False       False       False
# 150149       False       False       False       False       False
#
#         store_8095  store_8121  store_8218  store_8222  store_8317  ...  \
# 0            False       False       False       False       False  ...
# ...

# %%
df = df.join(pd.get_dummies(df.store_id, prefix='store')).drop('store_id', axis=1)
df = df.join(pd.get_dummies(df.sku_id, prefix='item')).drop('sku_id', axis=1)

# %%
df
# Out:
#         total_price  base_price  is_featured_sku  is_display_sku  units_sold  \
# 0           99.0375    111.8625                0               0          20
# 1           99.0375     99.0375                0               0          28
# 2          133.9500    133.9500                0               0          19
# 3          133.9500    133.9500                0               0          44
# 4          141.0750    141.0750                0               0          52
# ...             ...         ...              ...             ...         ...
# 150145     235.8375    235.8375                0               0          38
# 150146     235.8375    235.8375                0               0          30
# 150147     357.6750    483.7875                1               1          31
# 150148     141.7875    191.6625                0               1          12
# 150149     234.4125    234.4125                0               0          15
#
# ...

# %%
model = RandomForestRegressor(n_jobs=-1)

X, y = df.drop('units_sold', axis=1), df['units_sold']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=40)

# %%
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_jobs=-1)

# %%
model.score(X_test, y_test)
# Out:
# 0.8290643548910137

# %%
y_pred = model.predict(X_test)
rmse = root_mean_squared_error(y_pred, y_test)
rmse
# Out:
# 17.72516489029612

# %%
plt.scatter(y_pred, y_test)
plt.plot(np.linspace(y_pred.min(), y_pred.max()), np.linspace(y_test.min(), y_test.max()) , color='green')

# %%
# hyperparameters
from sklearn.model_selection import GridSearchCV

param_grid = {
    'n_estimators' : [10, 20],
    'min_samples_split': [2,3]
}

model = RandomForestRegressor(n_jobs=-1)
grid_search = GridSearchCV(model, param_grid, verbose=2, cv=3)

grid_search.fit(X_train ,y_train)
# Out:
# Fitting 3 folds for each of 4 candidates, totalling 12 fits
# [CV] END ...............min_samples_split=2, n_estimators=10; total time=   7.4s
# [CV] END ...............min_samples_split=2, n_estimators=10; total time=   7.7s
# [CV] END ...............min_samples_split=2, n_estimators=10; total time=   7.7s
# [CV] END ...............min_samples_split=2, n_estimators=20; total time=  15.4s
# [CV] END ...............min_samples_split=2, n_estimators=20; total time=  13.0s
# [CV] END ...............min_samples_split=2, n_estimators=20; total time=  11.0s
# [CV] END ...............min_samples_split=3, n_estimators=10; total time=   8.3s
# [CV] END ...............min_samples_split=3, n_estimators=10; total time=   8.0s
# [CV] END ...............min_samples_split=3, n_estimators=10; total time=   9.9s
# [CV] END ...............min_samples_split=3, n_estimators=20; total time=  14.4s
# [CV] END ...............min_samples_split=3, n_estimators=20; total time=  15.2s
# ...

# %%
best_model = grid_search.best_estimator_

# %%
grid_search.best_params_
# Out:
# {'min_samples_split': 3, 'n_estimators': 20}

# %%
best_model.score(X_test, y_test)
# Out:
# 0.9679862187851936

# %%
# if you want to save the model

from sklearn.externals import joblib
joblib.dump(gs.best_estimator_, 'demand_forecasting.pkl')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[56], line 3
#       1 # if you want to save the model
# ----> 3 from sklearn.externals import joblib
#       4 joblib.dump(gs.best_estimator_, 'demand_forecasting.pkl')
#
# ImportError: cannot import name 'joblib' from 'sklearn.externals' (C:\Users\cdsom\anaconda3\Lib\site-packages\sklearn\externals\__init__.py)
